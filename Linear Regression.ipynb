# %%
import warnings
warnings.filterwarnings('ignore')
from timeit import default_timer as timer
from sklearn import metrics
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import os
import requests
from IPython.display import HTML
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
df = pd.read_csv("./googleplaystore.csv")
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content_Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art_&_Design     January 7, 2018               1.0.0
# 1  Art_&_Design_Pretend_Play    January 15, 2018               2.0.0
# 2               Art_&_Design      August 1, 2018               1.2.4
# 3               Art_&_Design        June 8, 2018  Varies with device
# 4    Art_&_Design_Creativity       June 20, 2018                 1.1
# 5               Art_&_Design      March 26, 2017                   1
# 6               Art_&_Design      April 26, 2018                 1.1
# 7               Art_&_Design       June 14, 2018            6.1.61.1
# 8               Art_&_Design  September 20, 2017               2.9.2
# 9    Art_&_Design_Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
df.Installs.describe()
# Out:
# count          10841
# unique            22
# top       1,000,000+
# freq            1579
# Name: Installs, dtype: object

# %%
df1 = df.copy()

# %%
df1.drop(["App", "Last Updated", "Current Ver", "Android Ver"], axis=1, inplace=True)
df1.shape
# Out:
# (10841, 9)

# %%
df2 = pd.get_dummies(df1, drop_first=True)

# %%
df2.columns
# Out:
# Index(['Rating', 'Category_ART_AND_DESIGN', 'Category_AUTO_AND_VEHICLES',
#        'Category_BEAUTY', 'Category_BOOKS_AND_REFERENCE', 'Category_BUSINESS',
#        'Category_COMICS', 'Category_COMMUNICATION', 'Category_DATING',
#        'Category_EDUCATION',
#        ...
#        'Genres_Tools_Education', 'Genres_Travel_&_Local',
#        'Genres_Travel_&_Local_Action_&_Adventure', 'Genres_Trivia',
#        'Genres_Trivia_Education', 'Genres_Video_Players_&_Editors',
#        'Genres_Video_Players_&_Editors_Creativity',
#        'Genres_Video_Players_&_Editors_Music_&_Video', 'Genres_Weather',
#        'Genres_Word'],
#       dtype='object', length=6735)

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df2, train_size = 0.7, random_state = 100)

# %%
df_train.shape, df_test.shape
# Out:
# ((7588, 6735), (3253, 6735))

# %%
y_train = df_train.pop("Rating")
X_train = df_train

# %%
X_train.head(10)
# Out:
#        Category_ART_AND_DESIGN  Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# 7727                         0                           0                0
# 7002                         0                           0                0
# 4444                         0                           0                0
# 4373                         0                           0                0
# 10028                        0                           0                0
# 1886                         0                           0                0
# 1080                         0                           0                0
# 5862                         0                           0                0
# 5039                         0                           0                0
# 10040                        0                           0                0
#
#        Category_BOOKS_AND_REFERENCE  Category_BUSINESS  Category_COMICS  \
# 7727                              0                  0                0
# 7002                              0                  0                0
# 4444                              0                  0                0
# 4373                              0                  0                0
# 10028                             0                  0                0
# 1886                              0                  0                0
# 1080                              0                  0                0
# 5862                              0                  0                0
# 5039                              0                  0                0
# 10040                             0                  0                0
#
#        Category_COMMUNICATION  Category_DATING  Category_EDUCATION  \
# 7727                        0                0                   0
# 7002                        0                0                   0
# 4444                        0                0                   0
# 4373                        1                0                   0
# 10028                       0                0                   0
# 1886                        0                0                   0
# 1080                        0                0                   0
# 5862                        0                0                   0
# 5039                        0                0                   0
# 10040                       0                0                   0
#
#        Category_ENTERTAINMENT  ...  Genres_Tools_Education  \
# 7727                        0  ...                       0
# 7002                        0  ...                       0
# 4444                        0  ...                       0
# 4373                        0  ...                       0
# 10028                       0  ...                       0
# 1886                        0  ...                       0
# 1080                        0  ...                       0
# 5862                        0  ...                       0
# 5039                        0  ...                       0
# 10040                       0  ...                       0
#
#        Genres_Travel_&_Local  Genres_Travel_&_Local_Action_&_Adventure  \
# 7727                       0                                         0
# 7002                       0                                         0
# 4444                       0                                         0
# 4373                       0                                         0
# 10028                      0                                         0
# 1886                       0                                         0
# 1080                       0                                         0
# 5862                       0                                         0
# 5039                       0                                         0
# 10040                      0                                         0
#
#        Genres_Trivia  Genres_Trivia_Education  Genres_Video_Players_&_Editors  \
# 7727               0                        0                               0
# 7002               0                        0                               0
# 4444               0                        0                               0
# 4373               0                        0                               0
# 10028              0                        0                               0
# 1886               0                        0                               0
# 1080               0                        0                               0
# 5862               0                        0                               0
# 5039               0                        0                               0
# 10040              0                        0                               0
#
#        Genres_Video_Players_&_Editors_Creativity  \
# 7727                                           0
# 7002                                           0
# 4444                                           0
# 4373                                           0
# 10028                                          0
# 1886                                           0
# 1080                                           0
# 5862                                           0
# 5039                                           0
# 10040                                          0
#
#        Genres_Video_Players_&_Editors_Music_&_Video  Genres_Weather  \
# 7727                                              0               0
# 7002                                              0               0
# 4444                                              0               0
# 4373                                              0               0
# 10028                                             0               0
# 1886                                              0               0
# 1080                                              0               0
# 5862                                              0               0
# 5039                                              0               0
# 10040                                             0               1
#
#        Genres_Word
# 7727             0
# 7002             0
# 4444             0
# 4373             0
# 10028            0
# 1886             0
# 1080             0
# 5862             0
# 5039             0
# 10040            0
#
# [10 rows x 6734 columns]

# %%
y_test = df_test.pop("Rating")
X_test = df_test

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from sklearn.linear_model import LinearRegression

params = {
    "n_jobs": -1,
    "copy_X": False
}
start = timer()
model = LinearRegression().fit(X_train, y_train)
train_patched = timer() - start
f"Intel® extension for Scikit-learn time: {train_patched:.2f} s"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 8
#       3 params = {
#       4     "n_jobs": -1,
#       5     "copy_X": False
#       6 }
#       7 start = timer()
# ----> 8 model = LinearRegression().fit(X_train, y_train)
#       9 train_patched = timer() - start
#      10 f"Intel® extension for Scikit-learn time: {train_patched:.2f} s"
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/_device_offload.py:88, in support_usm_ndarray.<locals>.decorator.<locals>.wrapper_with_self(self, *args, **kwargs)
#      86 @wraps(func)
#      87 def wrapper_with_self(self, *args, **kwargs):
# ---> 88     return wrapper_impl(self, *args, **kwargs)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/_device_offload.py:74, in support_usm_ndarray.<locals>.decorator.<locals>.wrapper_impl(obj, *args, **kwargs)
#      72 usm_iface = _extract_usm_iface(*args, **kwargs)
#      73 q, hostargs, hostkwargs = _get_host_inputs(*args, **kwargs)
# ---> 74 result = _run_on_device(func, q, obj, *hostargs, **hostkwargs)
#      75 if usm_iface is not None and hasattr(result, '__array_interface__'):
#      76     return _copy_to_usm(q, result)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/_device_offload.py:65, in _run_on_device(func, queue, obj, *args, **kwargs)
#      62         with sycl_context('gpu' if queue.sycl_device.is_gpu else 'cpu',
#      63                           host_offload_on_fail=host_offload):
#      64             return dispatch_by_obj(obj, func, *args, **kwargs)
# ---> 65 return dispatch_by_obj(obj, func, *args, **kwargs)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/_device_offload.py:53, in _run_on_device.<locals>.dispatch_by_obj(obj, func, *args, **kwargs)
#      51 def dispatch_by_obj(obj, func, *args, **kwargs):
#      52     if obj is not None:
# ---> 53         return func(obj, *args, **kwargs)
#      54     return func(*args, **kwargs)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/linear_model/_linear.py:330, in LinearRegression.fit(self, X, y, sample_weight)
#     326         _patching_status.write_log()
#     327         return super(LinearRegression, self).fit(
#     328             X, y=y, sample_weight=sample_weight
#     329         )
# --> 330 return _fit_linear(self, X, y, sample_weight=sample_weight)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/linear_model/_linear.py:144, in _fit_linear(self, X, y, sample_weight)
#     136 params = {
#     137     'X': X,
#     138     'y': y,
#    (...)
#     141     'multi_output': True,
#     142 }
#     143 if sklearn_check_version('0.23'):
# --> 144     X, y = _daal_validate_data(
#     145         self,
#     146         dtype=[np.float64, np.float32],
#     147         **params,
#     148     )
#     149 else:
#     150     X, y = _daal_check_X_y(**params)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/utils/base.py:69, in _daal_validate_data(self, X, y, reset, validate_separately, **check_params)
#      67         y = _daal_check_array(y, **check_y_params)
#      68     else:
# ---> 69         X, y = _daal_check_X_y(X, y, **check_params)
#      70     out = X, y
#      72 if check_params.get('ensure_2d', True):
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/utils/validation.py:528, in _daal_check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     517 X = _daal_check_array(
#     518     X, accept_sparse=accept_sparse,
#     519     accept_large_sparse=accept_large_sparse,
#    (...)
#     525     estimator=estimator
#     526 )
#     527 if multi_output:
# --> 528     y = _daal_check_array(y, accept_sparse='csr', force_all_finite=True,
#     529                           ensure_2d=False, dtype=None)
#     530 else:
#     531     y = column_or_1d(y, warn=True)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/utils/validation.py:386, in _daal_check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     382         raise ValueError("Found array with dim %d. %s expected <= 2."
#     383                          % (array.ndim, estimator_name))
#     385     if force_all_finite:
# --> 386         _daal_assert_all_finite(array,
#     387                                 allow_nan=force_all_finite == 'allow-nan')
#     389 if ensure_min_samples > 0:
#     390     n_samples = _num_samples(array)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/utils/validation.py:43, in _daal_assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#      41 if X.size < 32768:
#      42     if sklearn_check_version("1.1"):
# ---> 43         _assert_all_finite(X, allow_nan=allow_nan, msg_dtype=msg_dtype,
#      44                            estimator_name=estimator_name, input_name=input_name)
#      45     else:
#      46         _assert_all_finite(X, allow_nan=allow_nan, msg_dtype=msg_dtype)
#
# File /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.
